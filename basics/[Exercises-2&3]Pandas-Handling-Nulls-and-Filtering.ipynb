# %% [markdown]
# ![sslogo](https://github.com/stratascratch/stratascratch.github.io/raw/master/assets/sslogo.jpg)

# %% [markdown]
# # Quick Rendering Hack

# %% [markdown]
# #### For results requiring multiple tables, use the display class to format your results

# %%
class display(object):
    """Display HTML representation of multiple objects"""
    template = """<div style="float: left; padding: 10px;">
    <p style='font-family:"Courier New", Courier, monospace'>{0}</p>{1}
    </div>"""
    def __init__(self, *args):
        self.args = args
        
    def _repr_html_(self):
        return '\n'.join(self.template.format(a, eval(a)._repr_html_())
                         for a in self.args)
    
    def __repr__(self):
        return '\n\n'.join(a + '\n' + repr(eval(a))
                           for a in self.args)

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Operating on Null Values

# %%
data = pd.Series([3.1414, np.nan, 'hello world', None])
data
# Out:
# 0         3.1414
# 1            NaN
# 2    hello world
# 3           None
# dtype: object

# %% [markdown]
# #### Create a boolean mask for rows containing a non-null value

# %%
data.notnull()
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# dtype: bool

# %% [markdown]
# #### Create a table containing all non-null values from data using a masking operation

# %%
data[data.notnull()]
# Out:
# 0         3.1414
# 2    hello world
# dtype: object

# %% [markdown]
# ### Dropping null values

# %%
df = pd.DataFrame([[1,      np.nan, 2     ],
                   [2,      3,      5     ],
                   [np.nan, 4,      6     ],
                   [np.nan, np.nan, np.nan],
                   [6     , np.nan, np.nan]])
df
# Out:
#      0    1    2
# 0  1.0  NaN  2.0
# 1  2.0  3.0  5.0
# 2  NaN  4.0  6.0
# 3  NaN  NaN  NaN
# 4  6.0  NaN  NaN

# %% [markdown]
# #### Create a table with all non-null values from data using the dropna method

# %%
data.dropna()
# Out:
# 0         3.1414
# 2    hello world
# dtype: object

# %% [markdown]
# #### Create a table will all non-null rows from df

# %%
df.dropna()
# Out:
#      0    1    2
# 1  2.0  3.0  5.0

# %% [markdown]
# #### Create a table will all columns with less than three non-null values from df

# %%
df.dropna(axis='columns', thresh=3)
# Out:
#      0    2
# 0  1.0  2.0
# 1  2.0  5.0
# 2  NaN  6.0
# 3  NaN  NaN
# 4  6.0  NaN

# %% [markdown]
# ### Filling null values

# %%
data = pd.Series([1, np.nan, 2, None, 3], index=list('abcde'))
data
# Out:
# a    1.0
# b    NaN
# c    2.0
# d    NaN
# e    3.0
# dtype: float64

# %% [markdown]
# #### Create a table with all null values of data filled with 1

# %%
data.fillna(1)
# Out:
# a    1.0
# b    1.0
# c    2.0
# d    1.0
# e    3.0
# dtype: float64

# %% [markdown]
# #### Create a table with all null values of data filled using the forward-fill method

# %%
data.fillna(method='ffill')
# Out:
# a    1.0
# b    1.0
# c    2.0
# d    2.0
# e    3.0
# dtype: float64

# %% [markdown]
# #### Create a table with all null values of data filled using the back-fill method

# %%
data.fillna(method='bfill')
# Out:
# a    1.0
# b    2.0
# c    2.0
# d    3.0
# e    3.0
# dtype: float64

# %% [markdown]
# For ``DataFrame``s, the options are similar, but we can also specify an ``axis`` along which the fills take place:

# %%
df
# Out:
#      0    1    2
# 0  1.0  NaN  2.0
# 1  2.0  3.0  5.0
# 2  NaN  4.0  6.0
# 3  NaN  NaN  NaN
# 4  6.0  NaN  NaN

# %% [markdown]
# #### Create a table will all null values of df filled using  the forward-fill method down each column

# %%
df.fillna(method='ffill', axis='rows')
# Out:
#      0    1    2
# 0  1.0  NaN  2.0
# 1  2.0  3.0  5.0
# 2  2.0  4.0  6.0
# 3  2.0  4.0  6.0
# 4  6.0  4.0  6.0

# %% [markdown]
# # Connect to the Strata Scratch Datasets To Explore Our Datasets

# %% [markdown]
# This notebook will guide you through the process of connecting to the Strata Scratch database to query datasets. Simply download this notebook and follow the steps.

# %% [markdown]
# ## Connect to Strata Scratch
#
# Remember to input your username and password

# %% [markdown]
# ## Pull Data From Strata Scratch

# %%
db_data = pd.read_csv('../datasets/nfl_combine.csv')

# %%
db_data.head()
# Out:
#    year            name firstname   lastname position  heightfeet  \
# 0  2015  Ameer Abdullah     Ameer   Abdullah       RB           5
# 1  2015  Nelson Agholor    Nelson    Agholor       WR           6
# 2  2015       Jay Ajayi       Jay      Ajayi       RB           6
# 3  2015  Kwon Alexander      Kwon  Alexander      OLB           6
# 4  2015    Mario Alford     Mario     Alford       WR           5
#
#    heightinches  heightinchestotal  weight  arms  ...  vertical  broad  bench  \
# 0           9.0               69.0     205   0.0  ...      42.5  130.0   24.0
# 1           0.0               72.0     198   0.0  ...       0.0    0.0   12.0
# 2           0.0               72.0     221   0.0  ...      39.0  121.0   19.0
# 3           1.0               73.0     227   0.0  ...      36.0  121.0   24.0
# 4           8.0               68.0     180   0.0  ...      34.0  121.0   13.0
#
#    round        college  pick  pickround  picktotal  wonderlic  nflgrade
# 0    0.0       Nebraska   NaN          0          0        0.0       5.9
# 1    0.0            USC   NaN          0          0        0.0       5.6
# 2    0.0      Boise St.   NaN          0          0        0.0       6.0
# 3    0.0            LSU   NaN          0          0        0.0       5.4
# 4    0.0  West Virginia   NaN          0          0        0.0       5.3
#
# [5 rows x 26 columns]

# %% [markdown]
# # Basic Pandas Functionality

# %% [markdown]
# #### Print the information about db_data

# %%
db_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   year               1000 non-null   int64
#  1   name               1000 non-null   object
#  2   firstname          1000 non-null   object
#  3   lastname           1000 non-null   object
#  4   position           1000 non-null   object
#  5   heightfeet         1000 non-null   int64
#  6   heightinches       1000 non-null   float64
#  7   heightinchestotal  1000 non-null   float64
#  8   weight             1000 non-null   int64
#  9   arms               1000 non-null   float64
#  10  hands              1000 non-null   float64
#  11  fortyyd            1000 non-null   float64
#  12  twentyyd           1000 non-null   float64
#  13  tenyd              1000 non-null   float64
#  14  twentyss           1000 non-null   float64
#  15  threecone          1000 non-null   float64
#  16  vertical           1000 non-null   float64
#  17  broad              1000 non-null   float64
#  18  bench              1000 non-null   float64
#  19  round              1000 non-null   float64
#  20  college            891 non-null    object
#  21  pick               569 non-null    object
#  22  pickround          1000 non-null   int64
#  23  picktotal          1000 non-null   int64
#  24  wonderlic          1000 non-null   float64
#  25  nflgrade           1000 non-null   float64
# dtypes: float64(15), int64(5), object(6)
# memory usage: 203.2+ KB

# %% [markdown]
# #### Print the first 8 rows of db_data

# %%
db_data.head(8)
# Out:
#    year            name firstname   lastname position  heightfeet  \
# 0  2015  Ameer Abdullah     Ameer   Abdullah       RB           5
# 1  2015  Nelson Agholor    Nelson    Agholor       WR           6
# 2  2015       Jay Ajayi       Jay      Ajayi       RB           6
# 3  2015  Kwon Alexander      Kwon  Alexander      OLB           6
# 4  2015    Mario Alford     Mario     Alford       WR           5
# 5  2015  Javorius Allen  Javorius      Allen       RB           6
# 6  2015     Adrian Amos    Adrian       Amos       FS           6
# 7  2015   Dres Anderson      Dres   Anderson       WR           6
#
#    heightinches  heightinchestotal  weight  arms  ...  vertical  broad  bench  \
# 0           9.0               69.0     205   0.0  ...      42.5  130.0   24.0
# 1           0.0               72.0     198   0.0  ...       0.0    0.0   12.0
# 2           0.0               72.0     221   0.0  ...      39.0  121.0   19.0
# 3           1.0               73.0     227   0.0  ...      36.0  121.0   24.0
# 4           8.0               68.0     180   0.0  ...      34.0  121.0   13.0
# 5           0.0               72.0     221   0.0  ...      35.5  121.0   11.0
# 6           0.0               72.0     218   0.0  ...      35.5  122.0    0.0
# 7           1.0               73.0     187   0.0  ...       0.0    0.0   13.0
#
#    round        college  pick  pickround  picktotal  wonderlic  nflgrade
# 0    0.0       Nebraska   NaN          0          0        0.0       5.9
# 1    0.0            USC   NaN          0          0        0.0       5.6
# 2    0.0      Boise St.   NaN          0          0        0.0       6.0
# 3    0.0            LSU   NaN          0          0        0.0       5.4
# 4    0.0  West Virginia   NaN          0          0        0.0       5.3
# 5    0.0            USC   NaN          0          0        0.0       5.3
# 6    0.0       Penn St.   NaN          0          0        0.0       5.5
# 7    0.0           Utah   NaN          0          0        0.0       5.5
#
# [8 rows x 26 columns]

# %% [markdown]
# #### Print the last 10 rows of db_data

# %%
db_data.tail(10)
# Out:
#      year              name firstname   lastname position  heightfeet  \
# 990  2012       Greg Childs      Greg     Childs       WR           6
# 991  2012  Morris Claiborne    Morris  Claiborne       CB           5
# 992  2012       Danny Coale     Danny      Coale       WR           6
# 993  2012        Audie Cole     Audie       Cole      ILB           6
# 994  2012      B.J. Coleman      B.J.    Coleman       QB           6
# 995  2012       Tom Compton       Tom    Compton       OT           6
# 996  2012       Josh Cooper      Josh     Cooper       WR           5
# 997  2012    Quinton Coples   Quinton     Coples       DE           6
# 998  2012      Paul Cornick      Paul    Cornick       OT           6
# 999  2012        Aaron Corp     Aaron       Corp       QB           6
#
#      heightinches  heightinchestotal  weight    arms  ...  vertical  broad  \
# 990           3.0               75.0     219  34.125  ...      36.0  125.0
# 991          11.0               71.0     188  33.250  ...      34.0  118.0
# 992           0.0               72.0     201  30.625  ...      35.0  115.0
# 993           4.0               76.0     246   0.000  ...      35.0   78.0
# 994           3.0               75.0     233  31.625  ...       0.0  109.0
# 995           5.0               77.0     314  34.000  ...      30.0  108.0
# 996          11.0               71.0     190  31.000  ...      31.5  115.0
# 997           6.0               78.0     284  33.250  ...      31.5  109.0
# 998           5.0               77.0     310  35.000  ...       0.0    0.0
# 999           4.0               76.0     215  32.000  ...      31.5  106.0
#
#      bench  round               college     pick  pickround  picktotal  \
# 990   19.0    4.0              Arkansas  39(134)         39         39
# 991    0.0    1.0                   LSU     6(6)          6          6
# 992   12.0    5.0         Virginia Tech  17(152)         17         17
# 993   15.0    7.0  North Carolina State   3(210)          3          3
# 994    0.0    7.0           Chattanooga  36(243)         36         36
# 995   20.0    6.0          South Dakota  23(193)         23         23
# 996   11.0    0.0                   NaN      NaN          0          0
# 997   25.0    1.0        North Carolina   16(16)         16         16
# 998   25.0    0.0                   NaN      NaN          0          0
# 999    0.0    0.0                   NaN      NaN          0          0
#
#      wonderlic  nflgrade
# 990        0.0       0.0
# 991        4.0       0.0
# 992        0.0       0.0
# 993        0.0       0.0
# 994        0.0       0.0
# 995        0.0       0.0
# 996        0.0       0.0
# 997        0.0       0.0
# 998        0.0       0.0
# 999        0.0       0.0
#
# [10 rows x 26 columns]

# %% [markdown]
# #### Print the summary statistics of db_data

# %%
db_data.describe().T
# Out:
#                     count         mean        std     min      25%      50%  \
# year               1000.0  2013.923000   0.909889  2012.0  2013.00  2014.00
# heightfeet         1000.0     5.777000   0.416467     5.0     6.00     6.00
# heightinches       1000.0     4.455000   3.450390     0.0     2.00     4.00
# heightinchestotal  1000.0    73.779000   2.765161    66.0    72.00    74.00
# weight             1000.0   244.327000  45.872305   156.0   207.00   234.50
# arms               1000.0    10.681375  15.320730     0.0     0.00     0.00
# hands              1000.0     3.143500   4.514200     0.0     0.00     0.00
# fortyyd            1000.0     4.039420   1.752945     0.0     4.46     4.63
# twentyyd           1000.0     0.028940   0.274660     0.0     0.00     0.00
# tenyd              1000.0     0.413850   0.711509     0.0     0.00     0.00
# twentyss           1000.0     2.939400   2.070490     0.0     0.00     4.20
# threecone          1000.0     4.878450   3.418277     0.0     0.00     6.97
# vertical           1000.0    26.782500  13.349856     0.0    26.50    32.00
# broad              1000.0    93.197000  45.941123     0.0   100.00   113.00
# bench              1000.0    15.118000  10.708723     0.0     0.00    17.00
# round              1000.0     1.848000   2.457832     0.0     0.00     0.00
# pickround          1000.0     7.964000  11.098192     0.0     0.00     0.00
# picktotal          1000.0     7.964000  11.098192     0.0     0.00     0.00
# wonderlic          1000.0     0.004000   0.126491     0.0     0.00     0.00
# nflgrade           1000.0     3.466000   2.587443     0.0     0.00     5.10
#
#                          75%       max
# year               2015.0000  2015.000
# heightfeet            6.0000     6.000
# heightinches          6.4375    11.125
# heightinchestotal    76.0000    80.250
# weight              283.0000   369.000
# arms                 31.5000    36.750
# hands                 9.1250    11.000
# fortyyd               4.9100     5.740
# twentyyd              0.0000     2.750
# tenyd                 1.4600     1.920
# twentyss              4.4200     5.270
# threecone             7.2700     8.310
# vertical             35.1250    45.000
# broad               120.0000   147.000
# bench                23.0000    42.000
# round                 4.0000     8.000
# pickround            16.0000    48.000
# picktotal            16.0000    48.000
# wonderlic             0.0000     4.000
# nflgrade              5.4000     7.500

# %% [markdown]
# ### Filtering Dataframes
#
# Remember: the syntax for filtering DataFrames is similar to that used for boolean masking

# %%
data = pd.read_csv('../datasets/titanic.csv')

# %%
data.head()
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 name     sex   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    parch            ticket     fare cabin embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# #### Filter the data for females
#
# Remember: the head method can be used to make results more concise

# %%
data[data['sex'] == 'female']
# Out:
#      passengerid  survived  pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   name     sex   age  sibsp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0
# 882                       Dahlberg, Miss. Gerda Ulrika  female  22.0      0
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
#
#      parch            ticket     fare cabin embarked
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 8        2            347742  11.1333   NaN        S
# 9        0            237736  30.0708   NaN        C
# ..     ...               ...      ...   ...      ...
# 880      1            230433  26.0000   NaN        S
# 882      0              7552  10.5167   NaN        S
# 885      5            382652  29.1250   NaN        Q
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
#
# [314 rows x 12 columns]

# %% [markdown]
# #### Filter for names and age of passengers with fares greater than 50

# %%
data.loc[data['fare'] > 50, ['name', 'age']]
# Out:
#                                                   name   age
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 6                              McCarthy, Mr. Timothy J  54.0
# 27                      Fortune, Mr. Charles Alexander  19.0
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)   NaN
# ..                                                 ...   ...
# 856         Wick, Mrs. George Dennick (Mary Hitchcock)  45.0
# 863                  Sage, Miss. Dorothy Edith "Dolly"   NaN
# 867               Roebling, Mr. Washington Augustus II  31.0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  47.0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  56.0
#
# [160 rows x 2 columns]

# %% [markdown]
# ### Adding methods to filters

# %% [markdown]
# #### Print the number of second class passengers

# %%
data.pclass[data['pclass'] == 2].count()
# Out:
# 184

# %% [markdown]
# #### Print the survival rate of males in the third passenger class
#
# survival rate = mean of survived column

# %%
data.survived[(data['sex'] == 'male') & (data['pclass'] == 3)].mean()
# Out:
# 0.13544668587896252

# %% [markdown]
# #### Print the survival rate for women and children

# %%
data[(data['sex'] == 'female') | (data['age'] < 18)]['survived'].mean()
# Out:
# 0.6881720430107527

# %% [markdown]
# #### Print the survival rate of men. Then, print the survival rate of women.
#
# This type of of group based aggregation will become simpler in the next section

# %%
print(data[data['sex'] == 'male']['survived'].mean())
print(data[data['sex'] == 'female']['survived'].mean())
# Out:
# 0.18890814558058924
# 0.7420382165605095
