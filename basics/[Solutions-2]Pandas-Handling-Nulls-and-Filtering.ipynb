# %% [markdown]
# ![sslogo](https://github.com/stratascratch/stratascratch.github.io/raw/master/assets/sslogo.jpg)

# %% [markdown]
# # Quick Rendering Hack

# %% [markdown]
# #### For results requiring multiple tables, use the display class to format your results

# %%
class display(object):
    """Display HTML representation of multiple objects"""
    template = """<div style="float: left; padding: 10px;">
    <p style='font-family:"Courier New", Courier, monospace'>{0}</p>{1}
    </div>"""
    def __init__(self, *args):
        self.args = args
        
    def _repr_html_(self):
        return '\n'.join(self.template.format(a, eval(a)._repr_html_())
                         for a in self.args)
    
    def __repr__(self):
        return '\n\n'.join(a + '\n' + repr(eval(a))
                           for a in self.args)

# %%
import numpy as np
import pandas as pd

# %%
db_data = pd.read_csv('../datasets/nfl_combine.csv')

# %% [markdown]
# # Operating on Null Values

# %%
data = pd.Series([3.1414, np.nan, 'hello world', None])

# %% [markdown]
# #### Create a boolean mask for rows containing a non-null value

# %%
data.notnull()
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# dtype: bool

# %% [markdown]
# #### Create a table containing all non-null values from data using a masking operation

# %%
data[data.notnull()]
# Out:
# 0         3.1414
# 2    hello world
# dtype: object

# %% [markdown]
# ### Dropping null values

# %%
df = pd.DataFrame([[1,      np.nan, 2     ],
                   [2,      3,      5     ],
                   [np.nan, 4,      6     ],
                   [np.nan, np.nan, np.nan],
                   [6     , np.nan, np.nan]])
df
# Out:
#      0    1    2
# 0  1.0  NaN  2.0
# 1  2.0  3.0  5.0
# 2  NaN  4.0  6.0
# 3  NaN  NaN  NaN
# 4  6.0  NaN  NaN

# %% [markdown]
# #### Create a table with all non-null values from data using the dropna method

# %%
data.dropna()
# Out:
# 0         3.1414
# 2    hello world
# dtype: object

# %% [markdown]
# #### Create a table will all non-null rows from df

# %%
df.dropna()
# Out:
#      0    1    2
# 1  2.0  3.0  5.0

# %% [markdown]
# #### Create a table will all columns with less than three non-null values from df

# %%
df.dropna(axis='columns', thresh=3)
# Out:
#      0    2
# 0  1.0  2.0
# 1  2.0  5.0
# 2  NaN  6.0
# 3  NaN  NaN
# 4  6.0  NaN

# %% [markdown]
# ### Filling null values

# %%
data = pd.Series([1, np.nan, 2, None, 3], index=list('abcde'))
data
# Out:
# a    1.0
# b    NaN
# c    2.0
# d    NaN
# e    3.0
# dtype: float64

# %% [markdown]
# #### Create a table with all null values of data filled with 1

# %%
data.fillna(1)
# Out:
# a    1.0
# b    1.0
# c    2.0
# d    1.0
# e    3.0
# dtype: float64

# %% [markdown]
# #### Create a table with all null values of data filled using the forward-fill method

# %%
# forward-fill
data.fillna(method='ffill')
# Out:
# a    1.0
# b    1.0
# c    2.0
# d    2.0
# e    3.0
# dtype: float64

# %% [markdown]
# #### Create a table with all null values of data filled using the back-fill method

# %%
# back-fill
data.fillna(method='bfill')
# Out:
# a    1.0
# b    2.0
# c    2.0
# d    3.0
# e    3.0
# dtype: float64

# %% [markdown]
# For ``DataFrame``s, the options are similar, but we can also specify an ``axis`` along which the fills take place:

# %%
df
# Out:
#      0    1    2
# 0  1.0  NaN  2.0
# 1  2.0  3.0  5.0
# 2  NaN  4.0  6.0
# 3  NaN  NaN  NaN
# 4  6.0  NaN  NaN

# %% [markdown]
# #### Create a table will all null values of df filled using  the forward-fill method down each column

# %%
df.fillna(method='ffill', axis=0)
# Out:
#      0    1    2
# 0  1.0  NaN  2.0
# 1  2.0  3.0  5.0
# 2  2.0  4.0  6.0
# 3  2.0  4.0  6.0
# 4  6.0  4.0  6.0

# %% [markdown]
# # Import Dataset

# %% [markdown]
# ## Import dataset

# %%
#import nfl_combine

# %%
db_data.head()
# Out:
#    year            name firstname   lastname position  heightfeet  \
# 0  2015  Ameer Abdullah     Ameer   Abdullah       RB           5
# 1  2015  Nelson Agholor    Nelson    Agholor       WR           6
# 2  2015       Jay Ajayi       Jay      Ajayi       RB           6
# 3  2015  Kwon Alexander      Kwon  Alexander      OLB           6
# 4  2015    Mario Alford     Mario     Alford       WR           5
#
#   heightinches heightinchestotal  weight    arms  ... vertical  broad  bench  \
# 0       9.0000           69.0000     205  0.0000  ...     42.5  130.0   24.0
# 1       0.0000           72.0000     198  0.0000  ...      0.0    0.0   12.0
# 2       0.0000           72.0000     221  0.0000  ...     39.0  121.0   19.0
# 3       1.0000           73.0000     227  0.0000  ...     36.0  121.0   24.0
# 4       8.0000           68.0000     180  0.0000  ...     34.0  121.0   13.0
#
#    round        college  pick  pickround  picktotal  wonderlic  nflgrade
# 0    0.0       Nebraska  None          0          0        0.0       5.9
# 1    0.0            USC  None          0          0        0.0       5.6
# 2    0.0      Boise St.  None          0          0        0.0       6.0
# 3    0.0            LSU  None          0          0        0.0       5.4
# 4    0.0  West Virginia  None          0          0        0.0       5.3
#
# [5 rows x 26 columns]

# %% [markdown]
# # Basic Pandas Functionality

# %% [markdown]
# #### Print the information about db_data

# %%
db_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4947 entries, 0 to 4946
# Data columns (total 26 columns):
# year                 4947 non-null int64
# name                 4947 non-null object
# firstname            4947 non-null object
# lastname             4947 non-null object
# position             4947 non-null object
# heightfeet           4947 non-null int64
# heightinches         4947 non-null object
# heightinchestotal    4947 non-null object
# weight               4947 non-null int64
# arms                 4947 non-null object
# hands                4947 non-null object
# fortyyd              4947 non-null float64
# twentyyd             4947 non-null float64
# tenyd                4947 non-null float64
# twentyss             4947 non-null float64
# threecone            4947 non-null float64
# vertical             4947 non-null float64
# broad                4947 non-null float64
# bench                4947 non-null float64
# round                4947 non-null float64
# college              3478 non-null object
# pick                 3156 non-null object
# pickround            4947 non-null int64
# picktotal            4947 non-null int64
# wonderlic            4947 non-null float64
# nflgrade             4947 non-null float64
# dtypes: float64(11), int64(5), object(10)
# memory usage: 1004.9+ KB

# %% [markdown]
# #### Print the first 8 rows of db_data

# %%
db_data.head(8)
# Out:
#    year            name firstname   lastname position  heightfeet  \
# 0  2015  Ameer Abdullah     Ameer   Abdullah       RB           5
# 1  2015  Nelson Agholor    Nelson    Agholor       WR           6
# 2  2015       Jay Ajayi       Jay      Ajayi       RB           6
# 3  2015  Kwon Alexander      Kwon  Alexander      OLB           6
# 4  2015    Mario Alford     Mario     Alford       WR           5
# 5  2015  Javorius Allen  Javorius      Allen       RB           6
# 6  2015     Adrian Amos    Adrian       Amos       FS           6
# 7  2015   Dres Anderson      Dres   Anderson       WR           6
#
#   heightinches heightinchestotal  weight    arms  ... vertical  broad  bench  \
# 0       9.0000           69.0000     205  0.0000  ...     42.5  130.0   24.0
# 1       0.0000           72.0000     198  0.0000  ...      0.0    0.0   12.0
# 2       0.0000           72.0000     221  0.0000  ...     39.0  121.0   19.0
# 3       1.0000           73.0000     227  0.0000  ...     36.0  121.0   24.0
# 4       8.0000           68.0000     180  0.0000  ...     34.0  121.0   13.0
# 5       0.0000           72.0000     221  0.0000  ...     35.5  121.0   11.0
# 6       0.0000           72.0000     218  0.0000  ...     35.5  122.0    0.0
# 7       1.0000           73.0000     187  0.0000  ...      0.0    0.0   13.0
#
#    round        college  pick  pickround  picktotal  wonderlic  nflgrade
# 0    0.0       Nebraska  None          0          0        0.0       5.9
# 1    0.0            USC  None          0          0        0.0       5.6
# 2    0.0      Boise St.  None          0          0        0.0       6.0
# 3    0.0            LSU  None          0          0        0.0       5.4
# 4    0.0  West Virginia  None          0          0        0.0       5.3
# 5    0.0            USC  None          0          0        0.0       5.3
# 6    0.0       Penn St.  None          0          0        0.0       5.5
# 7    0.0           Utah  None          0          0        0.0       5.5
#
# [8 rows x 26 columns]

# %% [markdown]
# #### Print the last 10 rows of db_data

# %%
db_data.tail(10)
# Out:
#       year            name firstname lastname position  heightfeet  \
# 4937  1999     Jerry Wisne     Jerry    Wisne       OG           6
# 4938  1999        Joe Wong       Joe     Wong       OT           6
# 4939  1999    Damien Woody    Damien    Woody       OC           6
# 4940  1999       Mark Word      Mark     Word      OLB           6
# 4941  1999  Anthony Wright   Anthony   Wright       QB           6
# 4942  1999    Daren Yancey     Daren   Yancey       DT           6
# 4943  1999     Craig Yeast     Craig    Yeast       WR           5
# 4944  1999      Ryan Young      Ryan    Young       OT           6
# 4945  1999   Peppi Zellner     Peppi  Zellner       DE           6
# 4946  1999    Amos Zereoue      Amos  Zereoue       RB           5
#
#      heightinches heightinchestotal  weight    arms  ... vertical  broad  \
# 4937       7.0000           79.0000     306  0.0000  ...     28.0  100.0
# 4938       6.0000           78.0000     314  0.0000  ...     27.0  100.0
# 4939       3.0000           75.0000     328  0.0000  ...     28.5  100.0
# 4940       5.0000           77.0000     258  0.0000  ...     31.5  115.0
# 4941       2.0000           74.0000     195  0.0000  ...     31.0  116.0
# 4942       6.0000           78.0000     303  0.0000  ...     26.5   97.0
# 4943       8.0000           68.0000     164  0.0000  ...     32.5  112.0
# 4944       6.0000           78.0000     335  0.0000  ...      0.0    0.0
# 4945       5.0000           77.0000     246  0.0000  ...     35.5  122.0
# 4946       8.0000           68.0000     203  0.0000  ...      0.0    0.0
#
#       bench  round            college     pick  pickround  picktotal  \
# 4937   30.0    5.0         Notre Dame  10(143)         10         10
# 4938   22.0    7.0      Brigham Young  38(244)         38         38
# 4939   26.0    1.0     Boston College   17(17)         17         17
# 4940   16.0    0.0               None     None          0          0
# 4941    0.0    0.0               None     None          0          0
# 4942    0.0    6.0      Brigham Young  19(188)         19         19
# 4943    0.0    4.0           Kentucky    3(98)          3          3
# 4944   20.0    7.0       Kansas State  17(223)         17         17
# 4945   20.0    4.0  Fort Valley State  37(132)         37         37
# 4946    0.0    3.0      West Virginia   34(95)         34         34
#
#       wonderlic  nflgrade
# 4937        0.0       0.0
# 4938        0.0       0.0
# 4939        0.0       0.0
# 4940        0.0       0.0
# 4941       16.0       0.0
# 4942        0.0       0.0
# 4943        0.0       0.0
# 4944        0.0       0.0
# 4945        0.0       0.0
# 4946        0.0       0.0
#
# [10 rows x 26 columns]

# %% [markdown]
# #### Print the summary statistics of db_data

# %%
db_data.describe().T
# Out:
#              count         mean        std     min       25%      50%  \
# year        4947.0  2007.132201   5.029664  1999.0  2003.000  2007.00
# heightfeet  4947.0     5.805337   0.395981     5.0     6.000     6.00
# weight      4947.0   245.579745  45.639366   155.0   208.000   237.00
# fortyyd     4947.0     4.610386   0.974087     0.0     4.530     4.69
# twentyyd    4947.0     0.073734   0.432330     0.0     0.000     0.00
# tenyd       4947.0     0.129149   0.436941     0.0     0.000     0.00
# twentyss    4947.0     3.298106   1.907526     0.0     3.835     4.24
# threecone   4947.0     1.503002   2.929683     0.0     0.000     0.00
# vertical    4947.0    28.741257  11.596749     0.0    28.000    32.50
# broad       4947.0    95.944006  41.826340     0.0   101.000   112.00
# bench       4947.0    15.723873  10.840896     0.0     0.000    18.00
# round       4947.0     2.435415   2.476746     0.0     0.000     2.00
# pickround   4947.0    11.318981  12.262220     0.0     0.000     7.00
# picktotal   4947.0    11.318981  12.262220     0.0     0.000     7.00
# wonderlic   4947.0     1.144532   5.524047     0.0     0.000     0.00
# nflgrade    4947.0     0.700627   1.813870     0.0     0.000     0.00
#
#                 75%      max
# year        2012.00  2015.00
# heightfeet     6.00     6.00
# weight       289.00   386.00
# fortyyd        4.99     6.05
# twentyyd       0.00     2.98
# tenyd          0.00     1.92
# twentyss       4.47     5.56
# threecone      0.00     8.31
# vertical      35.50    46.00
# broad        119.00   147.00
# bench         24.00    51.00
# round          5.00     8.00
# pickround     21.00    53.00
# picktotal     21.00    53.00
# wonderlic      0.00    48.00
# nflgrade       0.00     7.50

# %% [markdown]
# ### Filtering Dataframes
#
# Remember: the syntax for filtering DataFrames is similar to that used for boolean masking

# %%
#import titanic

# %%
data.head()
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 name     sex age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38      1
# 2                             Heikkinen, Miss. Laina  female  26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35      1
# 4                           Allen, Mr. William Henry    male  35      0
#
#    parch            ticket     fare cabin embarked
# 0      0         A/5 21171   7.2500  None        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250  None        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500  None        S

# %% [markdown]
# #### Filter the data for females
#
# Remember: the head method can be used to make results more concise

# %%
data[data.sex == 'female'].head()
# Out:
#    passengerid  survived  pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 8            9         1       3
# 9           10         1       2
#
#                                                 name     sex age  sibsp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38      1
# 2                             Heikkinen, Miss. Laina  female  26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35      1
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14      1
#
#    parch            ticket     fare cabin embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250  None        S
# 3      0            113803  53.1000  C123        S
# 8      2            347742  11.1333  None        S
# 9      0            237736  30.0708  None        C

# %% [markdown]
# #### Filter for names and age of passengers with fares greater than 50

# %%
data.loc[data.fare > 50, ['name', 'age']].head()
# Out:
#                                                  name   age
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...    38
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)    35
# 6                             McCarthy, Mr. Timothy J    54
# 27                     Fortune, Mr. Charles Alexander    19
# 31     Spencer, Mrs. William Augustus (Marie Eugenie)  None

# %% [markdown]
# ### Adding methods to filters

# %% [markdown]
# #### Print the number of second class passengers

# %%
data.pclass[data.pclass == 2].count()
# Out:
# 184

# %% [markdown]
# #### Print the survival rate of males in the third passenger class
#
# survival rate = mean of survived column

# %%
data.survived[(data.sex == 'male')&(data.pclass == 3)].mean()
# Out:
# 0.13544668587896252

# %% [markdown]
# #### Print the survival rate for women and children

# %%
data.survived[(data.sex == 'female')|(data.age < 18)].mean()
# Out:
# 0.6881720430107527

# %% [markdown]
# #### Print the survival rate of men. Then, print the survival rate of women.
#
# This type of of group based aggregation will become simpler in the next section

# %%
print(data.survived[data.sex == 'male'].mean())
print(data.survived[data.sex == 'female'].mean())
# Out:
# 0.18890814558058924
# 0.7420382165605095
